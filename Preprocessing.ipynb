# %%
import pandas as pd

# %%
xls_file = "news_category_dataset.xls"
df = pd.read_csv(xls_file)

# %%
df.to_csv("news_category_dataset.csv", index=False)
print("✅ Conversion done: news_category_dataset.csv created")
# Out:
# ✅ Conversion done: news_category_dataset.csv created

# %%
import re
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Mohd
# [nltk_data]     Sameer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("news_category_dataset.csv")

# %%
# Fill missing short_description with empty string
df['short_description'] = df['short_description'].fillna("")

# %%
# Combine headline + short_description
df['text'] = df['headline'].astype(str) + " " + df['short_description'].astype(str)

# %%
# Function to clean text
def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", '', text, flags=re.MULTILINE)  # remove links
    text = re.sub(r'[^a-z\s]', '', text)  # keep only letters
    tokens = [word for word in text.split() if word not in stop_words]
    return " ".join(tokens)

# %%
df['clean_text'] = df['text'].apply(clean_text)

# %%
# Save preprocessed data
df.to_csv("news_dataset_cleaned.csv", index=False)
print("✅ Preprocessing done! Saved as news_dataset_cleaned.csv")
# Out:
# ✅ Preprocessing done! Saved as news_dataset_cleaned.csv
